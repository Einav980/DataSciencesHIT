# %%
# imports and setup

import numpy as np
import pandas as pd

# sklearn imports
from sklearn import metrics
from sklearn import preprocessing, linear_model, model_selection
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# helper for logistic regression explanations
from scipy.special import expit
from scipy.special import logit

# visualization libraries 
import matplotlib.pyplot as plt
# %matplotlib inline  
plt.rcParams['figure.figsize'] = (20, 10)

from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# %%
#load the csv file with numbers only
dfML = pd.read_csv("DataFrame_final_ML.csv",index_col=0).copy()

# %%
#drow scatter plot 

plt.scatter(x=dfML['Recommend_to_friend'],y=dfML['EPS_next_Y'],c='#11dcca',marker='*',label='reccomend')
plt.scatter(x=dfML['Approve_of_CEO'],y=dfML['EPS_next_Y'],c='#465157',marker='*',label='approve')

plt.legend(numpoints=1,loc=4)
plt.xlabel('different reviews')
plt.ylabel('EPS_next_Y')
plt.show()

# %%
#drow scatter plot 

plt.scatter(x=dfML['Recommend_to_friend'],y=dfML['EPS_next_Y'],c='#11dcca',marker='*',label='recommend')
plt.scatter(x=dfML['rating'],y=dfML['EPS_next_Y'],c='#465157',marker='*',label='rating')

plt.legend(numpoints=1,loc=4)
plt.xlabel('different reviews')
plt.ylabel('EPS_next_Y')
plt.show()

# %%
#one dination machine learning 

lr1 = linear_model.LinearRegression() # create a linear regression object

# scikit-learn doesn't work as well with pandas, so we have to extract values 
x = dfML['rating'].values.reshape(dfML['rating'].shape[0],1)
y = dfML['EPS_next_Y'].values.reshape(dfML['EPS_next_Y'].shape[0],1)

#tests for model
X_train, X_test, y_train, y_test = train_test_split(x, y,test_size=0.1, random_state=41)

lr1.fit(X=X_test, y=y_test)

plt.scatter(X_test, y_test,  color='#465157')
plt.plot(X_test, lr1.predict(X_test), color='#f9ac00', linewidth=3)

#validation of data test
print ("test:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_test,y_test))


#run model
lr1.fit(X=X_train, y=y_train)

plt.scatter(X_train, y_train,  color='#465157')
plt.plot(X_train, lr1.predict(X_train), color='#f9ac00', linewidth=3)


#validation of data 
print ("\ntrain:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_train,y_train))

plt.xlabel('rating')
plt.ylabel('EPS_next_Y')
plt.show()
# Out:
# test:
# Slope: [[205.46531882]]
# Intercept: [-598.90880513]
# R2: 0.3733046526621102
#
# train:
# Slope: [[168.71605914]]
# Intercept: [-460.43431082]
# R2: 0.2725679503662708

# %%
#one dination machine learning 

lr1 = linear_model.LinearRegression() # create a linear regression object

# scikit-learn doesn't work as well with pandas, so we have to extract values 
x = dfML['Recommend_to_friend'].values.reshape(dfML['Recommend_to_friend'].shape[0],1)
y = dfML['EPS_next_Y'].values.reshape(dfML['EPS_next_Y'].shape[0],1)

#tests for model
X_train, X_test, y_train, y_test = train_test_split(x, y,test_size=0.1, random_state=41)

lr1.fit(X=X_test, y=y_test)

plt.scatter(X_test, y_test,  color='#465157')
plt.plot(X_test, lr1.predict(X_test), color='#f9ac00', linewidth=3)

#validation of data test
print ("test:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_test,y_test))


#run model
lr1.fit(X=X_train, y=y_train)

plt.scatter(X_train, y_train,  color='#465157')
plt.plot(X_train, lr1.predict(X_train), color='#f9ac00', linewidth=3)


#validation of data 
print ("\ntrain:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_train,y_train))

plt.xlabel('Recommend_to_friend')
plt.ylabel('EPS_next_Y')
plt.show()
# Out:
# test:
# Slope: [[89.02596252]]
# Intercept: [-141.81835325]
# R2: 0.2349919803072923
#
# train:
# Slope: [[80.51172362]]
# Intercept: [-116.40714295]
# R2: 0.18448610429436874

# %%
#one dination machine learning 

lr1 = linear_model.LinearRegression() # create a linear regression object

# scikit-learn doesn't work as well with pandas, so we have to extract values 
x = dfML['rating'].values.reshape(dfML['rating'].shape[0],1)
y = dfML['EPS_this_Y'].values.reshape(dfML['EPS_this_Y'].shape[0],1)


#tests for model
X_train, X_test, y_train, y_test = train_test_split(x, y,test_size=0.1, random_state=41)

lr1.fit(X=X_test, y=y_test)

plt.scatter(X_test, y_test,  color='#465157')
plt.plot(X_test, lr1.predict(X_test), color='#f9ac00', linewidth=3)

#validation of data test
print ("test:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_test,y_test))


#run model
lr1.fit(X=X_train, y=y_train)

plt.scatter(X_train, y_train,  color='#465157')
plt.plot(X_train, lr1.predict(X_train), color='#f9ac00', linewidth=3)


#validation of data 
print ("\ntrain:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_train,y_train))

plt.xlabel('rating')
plt.ylabel('EPS_this_Y')
plt.show()
# Out:
# test:
# Slope: [[163.35195979]]
# Intercept: [-549.40020812]
# R2: 0.11131456669158746
#
# train:
# Slope: [[127.71884317]]
# Intercept: [-407.24932612]
# R2: 0.10012009312472292

# %%
#one dination machine learning 

lr1 = linear_model.LinearRegression() # create a linear regression object

# scikit-learn doesn't work as well with pandas, so we have to extract values 
x = dfML['Recommend_to_friend'].values.reshape(dfML['Recommend_to_friend'].shape[0],1)
y = dfML['EPS_this_Y'].values.reshape(dfML['EPS_this_Y'].shape[0],1)

#tests for model
X_train, X_test, y_train, y_test = train_test_split(x, y,test_size=0.1, random_state=41)

lr1.fit(X=X_test, y=y_test)

plt.scatter(X_test, y_test,  color='#465157')
plt.plot(X_test, lr1.predict(X_test), color='#f9ac00', linewidth=3)

#validation of data test
print ("test:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_test,y_test))


#run model
lr1.fit(X=X_train, y=y_train)

plt.scatter(X_train, y_train,  color='#465157')
plt.plot(X_train, lr1.predict(X_train), color='#f9ac00', linewidth=3)


#validation of data 
print ("\ntrain:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_train,y_train))

plt.xlabel('Recommend_to_friend')
plt.ylabel('EPS_this_Y')
plt.show()
# Out:
# test:
# Slope: [[66.25078506]]
# Intercept: [-170.96243542]
# R2: 0.061392977263275084
#
# train:
# Slope: [[64.18870963]]
# Intercept: [-157.46075312]
# R2: 0.07516437516073737

# %%
#one dination machine learning 

lr1 = linear_model.LinearRegression() # create a linear regression object

# scikit-learn doesn't work as well with pandas, so we have to extract values 
x = dfML['rating'].values.reshape(dfML['rating'].shape[0],1)
y = dfML['this_next_EPS'].values.reshape(dfML['this_next_EPS'].shape[0],1)

#tests for model
X_train, X_test, y_train, y_test = train_test_split(x, y,test_size=0.1, random_state=41)

lr1.fit(X=X_test, y=y_test)

plt.scatter(X_test, y_test,  color='#465157')
plt.plot(X_test, lr1.predict(X_test), color='#f9ac00', linewidth=3)

#validation of data test
print ("test:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_test,y_test))


#run model
lr1.fit(X=X_train, y=y_train)

plt.scatter(X_train, y_train,  color='#465157')
plt.plot(X_train, lr1.predict(X_train), color='#f9ac00', linewidth=3)


#validation of data 
print ("\ntrain:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_train,y_train))

plt.xlabel('rating')
plt.ylabel('EPS_this_Y + EPS_next_Y')
plt.show()
# Out:
# test:
# Slope: [[368.81727861]]
# Intercept: [-1148.30901325]
# R2: 0.3207482946072835
#
# train:
# Slope: [[296.43490231]]
# Intercept: [-867.68363694]
# R2: 0.2640982243573958

# %%
#one dination machine learning 

lr1 = linear_model.LinearRegression() # create a linear regression object

# scikit-learn doesn't work as well with pandas, so we have to extract values 
x = dfML['Recommend_to_friend'].values.reshape(dfML['Recommend_to_friend'].shape[0],1)
y = dfML['rating'].values.reshape(dfML['rating'].shape[0],1)

#tests for model
X_train, X_test, y_train, y_test = train_test_split(x, y,test_size=0.1, random_state=41)

lr1.fit(X=X_test, y=y_test)

plt.scatter(X_test, y_test,  color='#465157')
plt.plot(X_test, lr1.predict(X_test), color='#f9ac00', linewidth=3)

#validation of data test
print ("test:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_test,y_test))


#run model
lr1.fit(X=X_train, y=y_train)

plt.scatter(X_train, y_train,  color='#465157')
plt.plot(X_train, lr1.predict(X_train), color='#f9ac00', linewidth=3)


#validation of data 
print ("\ntrain:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_train,y_train))

plt.xlabel('Recommend_to_friend')
plt.ylabel('rating')
plt.show()
# Out:
# test:
# Slope: [[0.43582892]]
# Intercept: [2.2162275]
# R2: 0.6368914702608544
#
# train:
# Slope: [[0.46522683]]
# Intercept: [2.07841138]
# R2: 0.6432991383117934

# %%
#3 dination machine learning 

lr1 = linear_model.LinearRegression() # create a linear regression object

x = dfML[['rating',"Recommend_to_friend","Approve_of_CEO"]]
y = dfML['EPS_next_Y']



#tests for model
X_train, X_test, y_train, y_test = train_test_split(x, y,test_size=0.1, random_state=41)

lr1.fit(X=X_test, y=y_test)

#validation of data test
print ("test:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_test,y_test))


#run model
lr1.fit(X=X_train, y=y_train)


#validation of data 
print ("\ntrain:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_train,y_train))
# Out:
# test:
# Slope: [206.14978156  -1.82612793   1.98542503]
# Intercept: -603.4067993254591
# R2: 0.373397672907665
#
# train:
# Slope: [158.40254944   3.18887187   7.20378078]
# Intercept: -462.81437645299354
# R2: 0.27390875091823474

# %%
print(dfML.corr())
pd.plotting.scatter_matrix(dfML[['rating',"Recommend_to_friend","Approve_of_CEO", "EPS_next_Y"]], figsize=(10, 10), diagonal='kde')
plt.show()
# Out:
#                      Unnamed: 0.1    contry  Industry  Market_Cap       P_E  \
# Unnamed: 0.1             1.000000 -0.014720  0.071050   -0.015527 -0.018328
# contry                  -0.014720  1.000000 -0.003372   -0.068436 -0.016905
# Industry                 0.071050 -0.003372  1.000000    0.021855 -0.015496
# Market_Cap              -0.015527 -0.068436  0.021855    1.000000  0.031338
# P_E                     -0.018328 -0.016905 -0.015496    0.031338  1.000000
# Avg_Volume               0.030478 -0.082750 -0.003438    0.128643  0.003318
# EPS_this_Y              -0.089701 -0.026530 -0.036351    0.024937  0.020704
# EPS_next_Y              -0.004435 -0.036745 -0.002235    0.046318 -0.007131
# rating                   0.006397 -0.048431 -0.008907    0.053811  0.007056
# Global_Company_Size      0.002250  0.090584 -0.061198   -0.127197 -0.034963
# Founded                  0.019699 -0.015658  0.045197   -0.084450 -0.022015
# ...

# %%
lr = linear_model.LinearRegression() # create a linear regression object

# scikit-learn doesn't work as well with pandas, so we have to extract values 
x = dfML[["inSNP500", "rating","Revenue", "Global_Company_Size",  "EPS_this_Y" , "P_E", 'Industry', "contry", "Market_Cap", 'Founded', 'Index' ]]
y = dfML['EPS_next_Y']

#tests for model
X_train, X_test, y_train, y_test = train_test_split(x, y,test_size=0.1, random_state=41)

lr1.fit(X=X_test, y=y_test)

#validation of data test
print ("test:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_test,y_test))


#run model
lr1.fit(X=X_train, y=y_train)


#validation of data 
print ("\ntrain:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_train,y_train))
# Out:
# test:
# Slope: [-4.76941104e+01  2.04573600e+02 -6.07213749e+00  2.86391251e+00
#   9.32612530e-03 -6.15981118e+00  7.99552569e-02  2.56703558e+01
#   5.55622334e-10  1.57682617e-01 -1.63780351e+01]
# Intercept: -891.2673663127931
# R2: 0.39260635642674824
#
# train:
# Slope: [-1.75226507e+01  1.62097940e+02 -1.27639257e+00  1.70964857e-01
#   7.07281533e-02 -4.51519694e+00  7.75100590e-02 -8.39190525e+00
#   1.35201493e-10  4.43958779e-01 -2.68662787e+01]
# Intercept: -1270.7138870996591
# R2: 0.2982409689847124

# %%
lr = linear_model.LinearRegression() # create a linear regression object

dfML["EPS_this_Y_rating"]=dfML["rating"]*dfML["EPS_this_Y"]

# scikit-learn doesn't work as well with pandas, so we have to extract values 
x = dfML[["rating","EPS_this_Y","EPS_this_Y_rating", "inSNP500","Revenue", "Global_Company_Size",  "EPS_this_Y" , "P_E", 'Industry', "contry", "Market_Cap", 'Founded', 'Index' ]].values.reshape(dfML[["rating","EPS_this_Y","EPS_this_Y_rating"]].shape[0],13)
y = dfML['EPS_next_Y'].values.reshape(dfML['EPS_next_Y'].shape[0],1)

#tests for model
X_train, X_test, y_train, y_test = train_test_split(x, y,test_size=0.1, random_state=41)

lr1.fit(X=X_test, y=y_test)

#validation of data test
print ("test:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_test,y_test))


#run model
lr1.fit(X=X_train, y=y_train)


#validation of data 
print ("\ntrain:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_train,y_train))
# Out:
# test:
# Slope: [[ 1.96260618e+02 -2.61430326e-01  1.39349883e-01 -4.93531513e+01
#   -6.17236342e+00  2.06739101e+00 -2.61546159e-01 -5.69101717e+00
#    4.02906869e-02  2.37427483e+01  5.69569646e-10  1.35980876e-01
#   -1.35576173e+01]]
# Intercept: [-822.02540207]
# R2: 0.40782361846638404
#
# train:
# Slope: [[ 1.57058389e+02 -3.02091747e-01  1.73917159e-01 -1.34699818e+01
#   -1.39446958e+00  3.81240315e-01 -3.01838002e-01 -4.21604115e+00
#    7.17393449e-02 -8.28038711e+00  1.38920683e-10  3.96170594e-01
#   -2.66618192e+01]]
# Intercept: [-1165.708869]
# R2: 0.31669803902233384
