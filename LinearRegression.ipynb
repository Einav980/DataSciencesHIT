# %%
# imports and setup

import numpy as np
import pandas as pd

# sklearn imports
from sklearn import linear_model
from sklearn import metrics

# helper for logistic regression explanations
from scipy.special import expit
from scipy.special import logit

# visualization libraries 
import matplotlib.pyplot as plt
# %matplotlib inline  
plt.rcParams['figure.figsize'] = (20, 10)

from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# %%
#load the csv file with numbers only
dfML = pd.read_csv("DataFrame_final_ML.csv",index_col=0).copy()
dfML.drop(['Unnamed: 0.1'], axis = 1 , inplace =True)

# %%
#drow scatter plot 

plt.scatter(x=dfML['Recommend_to_friend'],y=dfML['EPS_next_Y'],c='#11dcca',marker='*',label='reccomend')
plt.scatter(x=dfML['Approve_of_CEO'],y=dfML['EPS_next_Y'],c='#465157',marker='*',label='approve')

plt.legend(numpoints=1,loc=4)
plt.xlabel('different reviews')
plt.ylabel('EPS_next_Y')
plt.show()

# %%
#drow scatter plot 

plt.scatter(x=dfML['Recommend_to_friend'],y=dfML['EPS_next_Y'],c='#11dcca',marker='*',label='recommend')
plt.scatter(x=dfML['rating'],y=dfML['EPS_next_Y'],c='#465157',marker='*',label='rating')

plt.legend(numpoints=1,loc=4)
plt.xlabel('different reviews')
plt.ylabel('EPS_next_Y')
plt.show()

# %%
#one dination machine learning 

lr1 = linear_model.LinearRegression() # create a linear regression object

# scikit-learn doesn't work as well with pandas, so we have to extract values 
x = dfML['rating'].values.reshape(dfML['rating'].shape[0],1)
y = dfML['EPS_next_Y'].values.reshape(dfML['EPS_next_Y'].shape[0],1)

#tests for model
X_train, X_test, y_train, y_test = split_to_train_and_test(x, y, 0.2, 41)

lr1.fit(X=X_test, y=y_test)

plt.scatter(X_test, y_test,  color='#465157')
plt.plot(X_test, lr1.predict(X_test), color='#f9ac00', linewidth=3)

#validation of data test
print ("test:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_test,y_test))


#run model
lr1.fit(X=X_train, y=y_train)

plt.scatter(X_train, y_train,  color='#465157')
plt.plot(X_train, lr1.predict(X_train), color='#f9ac00', linewidth=3)


#validation of data 
print ("\ntrain:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_train,y_train))

plt.xlabel('rating')
plt.ylabel('EPS_next_Y')
plt.show()
# Out:
# test:
# Slope: [[174.71844754]]
# Intercept: [-484.11696146]
# R2: 0.31114020979544876
#
# train:
# Slope: [[171.04251482]]
# Intercept: [-467.4792454]
# R2: 0.27223599738225823

# %%
#one dination machine learning 

lr1 = linear_model.LinearRegression() # create a linear regression object

# scikit-learn doesn't work as well with pandas, so we have to extract values 
x = dfML['Recommend_to_friend'].values.reshape(dfML['Recommend_to_friend'].shape[0],1)
y = dfML['EPS_next_Y'].values.reshape(dfML['EPS_next_Y'].shape[0],1)

#tests for model
X_train, X_test, y_train, y_test = split_to_train_and_test(x, y, 0.2, 41)

lr1.fit(X=X_test, y=y_test)

plt.scatter(X_test, y_test,  color='#465157')
plt.plot(X_test, lr1.predict(X_test), color='#f9ac00', linewidth=3)

#validation of data test
print ("test:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_test,y_test))


#run model
lr1.fit(X=X_train, y=y_train)

plt.scatter(X_train, y_train,  color='#465157')
plt.plot(X_train, lr1.predict(X_train), color='#f9ac00', linewidth=3)


#validation of data 
print ("\ntrain:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_train,y_train))

plt.xlabel('Recommend_to_friend')
plt.ylabel('EPS_next_Y')
plt.show()
# Out:
# test:
# Slope: [[81.39797465]]
# Intercept: [-122.04516284]
# R2: 0.20499334220052878
#
# train:
# Slope: [[80.73734529]]
# Intercept: [-114.87162561]
# R2: 0.1817760871456674

# %%
#one dination machine learning 

lr1 = linear_model.LinearRegression() # create a linear regression object

# scikit-learn doesn't work as well with pandas, so we have to extract values 
x = dfML['rating'].values.reshape(dfML['rating'].shape[0],1)
y = dfML['EPS_this_Y'].values.reshape(dfML['EPS_this_Y'].shape[0],1)


#tests for model
X_train, X_test, y_train, y_test = split_to_train_and_test(x, y, 0.2, 41)

lr1.fit(X=X_test, y=y_test)

plt.scatter(X_test, y_test,  color='#465157')
plt.plot(X_test, lr1.predict(X_test), color='#f9ac00', linewidth=3)

#validation of data test
print ("test:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_test,y_test))


#run model
lr1.fit(X=X_train, y=y_train)

plt.scatter(X_train, y_train,  color='#465157')
plt.plot(X_train, lr1.predict(X_train), color='#f9ac00', linewidth=3)


#validation of data 
print ("\ntrain:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_train,y_train))

plt.xlabel('rating')
plt.ylabel('EPS_this_Y')
plt.show()
# Out:
# test:
# Slope: [[145.97909024]]
# Intercept: [-477.91753145]
# R2: 0.12584288791712506
#
# train:
# Slope: [[138.662272]]
# Intercept: [-449.07093999]
# R2: 0.11289923132864321

# %%
#one dination machine learning 

lr1 = linear_model.LinearRegression() # create a linear regression object

# scikit-learn doesn't work as well with pandas, so we have to extract values 
x = dfML['Recommend_to_friend'].values.reshape(dfML['Recommend_to_friend'].shape[0],1)
y = dfML['EPS_this_Y'].values.reshape(dfML['EPS_this_Y'].shape[0],1)

#tests for model
X_train, X_test, y_train, y_test = split_to_train_and_test(x, y, 0.2, 41)

lr1.fit(X=X_test, y=y_test)

plt.scatter(X_test, y_test,  color='#465157')
plt.plot(X_test, lr1.predict(X_test), color='#f9ac00', linewidth=3)

#validation of data test
print ("test:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_test,y_test))


#run model
lr1.fit(X=X_train, y=y_train)

plt.scatter(X_train, y_train,  color='#465157')
plt.plot(X_train, lr1.predict(X_train), color='#f9ac00', linewidth=3)


#validation of data 
print ("\ntrain:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_train,y_train))

plt.xlabel('Recommend_to_friend')
plt.ylabel('EPS_this_Y')
plt.show()
# Out:
# test:
# Slope: [[67.77581796]]
# Intercept: [-174.64094932]
# R2: 0.08234378927171027
#
# train:
# Slope: [[69.26113787]]
# Intercept: [-175.73822042]
# R2: 0.08441196716764765

# %%
#one dination machine learning 

lr1 = linear_model.LinearRegression() # create a linear regression object

# scikit-learn doesn't work as well with pandas, so we have to extract values 
x = dfML['rating'].values.reshape(dfML['rating'].shape[0],1)
y = dfML['this_next_EPS'].values.reshape(dfML['this_next_EPS'].shape[0],1)

#tests for model
X_train, X_test, y_train, y_test = split_to_train_and_test(x, y, 0.2, 41)

lr1.fit(X=X_test, y=y_test)

plt.scatter(X_test, y_test,  color='#465157')
plt.plot(X_test, lr1.predict(X_test), color='#f9ac00', linewidth=3)

#validation of data test
print ("test:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_test,y_test))


#run model
lr1.fit(X=X_train, y=y_train)

plt.scatter(X_train, y_train,  color='#465157')
plt.plot(X_train, lr1.predict(X_train), color='#f9ac00', linewidth=3)


#validation of data 
print ("\ntrain:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_train,y_train))

plt.xlabel('rating')
plt.ylabel('EPS_this_Y + EPS_next_Y')
plt.show()
# Out:
# test:
# Slope: [[320.69753778]]
# Intercept: [-962.03449291]
# R2: 0.3162961635678194
#
# train:
# Slope: [[309.70478682]]
# Intercept: [-916.55018539]
# R2: 0.2762200172855743

# %%
#one dination machine learning 

lr1 = linear_model.LinearRegression() # create a linear regression object

# scikit-learn doesn't work as well with pandas, so we have to extract values 
x = dfML['Recommend_to_friend'].values.reshape(dfML['Recommend_to_friend'].shape[0],1)
y = dfML['rating'].values.reshape(dfML['rating'].shape[0],1)

#tests for model
X_train, X_test, y_train, y_test = split_to_train_and_test(x, y, 0.2, 41)

lr1.fit(X=X_test, y=y_test)

plt.scatter(X_test, y_test,  color='#465157')
plt.plot(X_test, lr1.predict(X_test), color='#f9ac00', linewidth=3)

#validation of data test
print ("test:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_test,y_test))


#run model
lr1.fit(X=X_train, y=y_train)

plt.scatter(X_train, y_train,  color='#465157')
plt.plot(X_train, lr1.predict(X_train), color='#f9ac00', linewidth=3)


#validation of data 
print ("\ntrain:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_train,y_train))

plt.xlabel('Recommend_to_friend')
plt.ylabel('rating')
plt.show()
# Out:
# test:
# Slope: [[0.45310364]]
# Intercept: [2.11408418]
# R2: 0.6232023093012244
#
# train:
# Slope: [[0.46452892]]
# Intercept: [2.08618827]
# R2: 0.6466598843159828

# %%
#3 dination machine learning 

lr1 = linear_model.LinearRegression() # create a linear regression object

x = dfML[['rating',"Recommend_to_friend","Approve_of_CEO"]]
y = dfML['EPS_next_Y']



#tests for model
X_train, X_test, y_train, y_test = split_to_train_and_test(x, y, 0.2, 41)

lr1.fit(X=X_test, y=y_test)

#validation of data test
print ("test:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_test,y_test))


#run model
lr1.fit(X=X_train, y=y_train)


#validation of data 
print ("\ntrain:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_train,y_train))
# Out:
# test:
# Slope: [162.27406226   2.91432851   9.7787642 ]
# Intercept: -488.06628898269764
# R2: 0.3136047103352888
#
# train:
# Slope: [163.52490176   1.32354677   6.86754974]
# Intercept: -472.46777517912506
# R2: 0.2732600402524

# %%
print(dfML.corr())
pd.plotting.scatter_matrix(dfML[['rating',"Recommend_to_friend","Approve_of_CEO", "EPS_next_Y"]], figsize=(10, 10), diagonal='kde')
plt.show()
# Out:
#                        contry  Industry  Market_Cap       P_E  Avg_Volume  \
# contry               1.000000 -0.002308   -0.066873 -0.026176   -0.083343
# Industry            -0.002308  1.000000    0.020754 -0.010481   -0.003645
# Market_Cap          -0.066873  0.020754    1.000000  0.041032    0.128405
# P_E                 -0.026176 -0.010481    0.041032  1.000000    0.007108
# Avg_Volume          -0.083343 -0.003645    0.128405  0.007108    1.000000
# EPS_this_Y          -0.026409 -0.036346    0.027005  0.057151    0.023602
# EPS_next_Y          -0.037020 -0.004199    0.047292  0.015523    0.034535
# rating              -0.045888 -0.007221    0.052624  0.107790    0.004940
# Global_Company_Size  0.090906 -0.059524   -0.125574 -0.050064   -0.044230
# Founded             -0.016980  0.047218   -0.084851 -0.035277   -0.018743
# Revenue              0.068560 -0.030606   -0.062965 -0.007692   -0.040143
# Recommend_to_friend -0.051858 -0.024792    0.018451  0.083231   -0.013989
# Approve_of_CEO      -0.078335 -0.050020    0.062629  0.021425   -0.041151
# inSNP500             0.108934  0.070297    0.296110  0.035911    0.125235
# Index               -0.109712  0.167427    0.106544  0.023210    0.055582
# this_next_EPS       -0.039147 -0.027933    0.045268  0.048873    0.035792
# recomend_rating     -0.052137 -0.019274    0.032489  0.096788   -0.007414
#
#                      EPS_this_Y  EPS_next_Y    rating  Global_Company_Size  \
# contry                -0.026409   -0.037020 -0.045888             0.090906
# Industry              -0.036346   -0.004199 -0.007221            -0.059524
# Market_Cap             0.027005    0.047292  0.052624            -0.125574
# P_E                    0.057151    0.015523  0.107790            -0.050064
# Avg_Volume             0.023602    0.034535  0.004940            -0.044230
# EPS_this_Y             1.000000    0.250448  0.339826            -0.011930
# EPS_next_Y             0.250448    1.000000  0.528743            -0.005790
# rating                 0.339826    0.528743  1.000000            -0.078506
# Global_Company_Size   -0.011930   -0.005790 -0.078506             1.000000
# Founded                0.025284    0.097325 -0.014720             0.184930
# Revenue               -0.024252   -0.055047 -0.061345             0.010157
# Recommend_to_friend    0.289849    0.431459  0.801176            -0.091175
# Approve_of_CEO         0.182779    0.291117  0.492690            -0.038150
# inSNP500               0.039029    0.004184  0.102970            -0.202795
# Index                 -0.010343   -0.039749  0.088141            -0.189739
# this_next_EPS          0.843400    0.731391  0.532814            -0.011617
# recomend_rating        0.323413    0.490211  0.917252            -0.090831
#
#                       Founded   Revenue  Recommend_to_friend  Approve_of_CEO  \
# contry              -0.016980  0.068560            -0.051858       -0.078335
# Industry             0.047218 -0.030606            -0.024792       -0.050020
# Market_Cap          -0.084851 -0.062965             0.018451        0.062629
# P_E                 -0.035277 -0.007692             0.083231        0.021425
# Avg_Volume          -0.018743 -0.040143            -0.013989       -0.041151
# EPS_this_Y           0.025284 -0.024252             0.289849        0.182779
# EPS_next_Y           0.097325 -0.055047             0.431459        0.291117
# rating              -0.014720 -0.061345             0.801176        0.492690
# Global_Company_Size  0.184930  0.010157            -0.091175       -0.038150
# Founded              1.000000  0.023030            -0.022923        0.039578
# Revenue              0.023030  1.000000            -0.066993       -0.057380
# Recommend_to_friend -0.022923 -0.066993             1.000000        0.515703
# Approve_of_CEO       0.039578 -0.057380             0.515703        1.000000
# inSNP500            -0.220012 -0.041195             0.100217        0.062499
# Index               -0.231490 -0.064439             0.096408        0.020139
# this_next_EPS        0.071823 -0.047633             0.443620        0.290313
# recomend_rating     -0.020910 -0.068146             0.973239        0.532439
#
#                      inSNP500     Index  this_next_EPS  recomend_rating
# contry               0.108934 -0.109712      -0.039147        -0.052137
# Industry             0.070297  0.167427      -0.027933        -0.019274
# Market_Cap           0.296110  0.106544       0.045268         0.032489
# P_E                  0.035911  0.023210       0.048873         0.096788
# Avg_Volume           0.125235  0.055582       0.035792        -0.007414
# EPS_this_Y           0.039029 -0.010343       0.843400         0.323413
# EPS_next_Y           0.004184 -0.039749       0.731391         0.490211
# rating               0.102970  0.088141       0.532814         0.917252
# Global_Company_Size -0.202795 -0.189739      -0.011617        -0.090831
# Founded             -0.220012 -0.231490       0.071823        -0.020910
# Revenue             -0.041195 -0.064439      -0.047633        -0.068146
# Recommend_to_friend  0.100217  0.096408       0.443620         0.973239
# Approve_of_CEO       0.062499  0.020139       0.290313         0.532439
# inSNP500             1.000000  0.217656       0.029814         0.106244
# Index                0.217656  1.000000      -0.029345         0.098014
# this_next_EPS        0.029814 -0.029345       1.000000         0.499868
# recomend_rating      0.106244  0.098014       0.499868         1.000000

# %%
lr = linear_model.LinearRegression() # create a linear regression object

# scikit-learn doesn't work as well with pandas, so we have to extract values 
x = dfML[["inSNP500", "rating","Revenue", "Global_Company_Size",  "EPS_this_Y" , "P_E", 'Industry', "contry", "Market_Cap", 'Founded', 'Index' ]]
y = dfML['EPS_next_Y']

#tests for model
X_train, X_test, y_train, y_test = split_to_train_and_test(x, y, 0.2, 41)

lr1.fit(X=X_test, y=y_test)

#validation of data test
print ("test:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_test,y_test))


#run model
lr1.fit(X=X_train, y=y_train)


#validation of data 
print ("\ntrain:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_train,y_train))
# Out:
# test:
# Slope: [-1.96002254e+01  1.70823075e+02 -2.44374737e+00  1.59241511e+00
#   1.87284064e-02  3.73355276e-01 -1.24438603e-01 -3.69204845e+01
#   3.61860686e-10  4.05439923e-01 -1.78096288e+01]
# Intercept: -1204.7894565868912
# R2: 0.33173086442016575
#
# train:
# Slope: [-2.06503593e+01  1.65784668e+02 -1.73198666e+00  5.41713678e-01
#   6.86356746e-02 -2.21004184e+01  9.06054296e-02  1.70029709e+00
#   1.45814522e-10  4.32758948e-01 -2.71554981e+01]
# Intercept: -1260.7600710237882
# R2: 0.30065953380548316

# %%
lr = linear_model.LinearRegression() # create a linear regression object

dfML["EPS_this_Y_rating"]=dfML["rating"]*dfML["EPS_this_Y"]


# scikit-learn doesn't work as well with pandas, so we have to extract values 
x = dfML[["rating","EPS_this_Y","EPS_this_Y_rating"]].values.reshape(dfML[["rating","EPS_this_Y","EPS_this_Y_rating"]].shape[0],3)
y = dfML['EPS_next_Y'].values.reshape(dfML['EPS_next_Y'].shape[0],1)

#tests for model
X_train, X_test, y_train, y_test = split_to_train_and_test(x, y, 0.2, 41)

lr1.fit(X=X_test, y=y_test)

#validation of data test
print ("test:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_test,y_test))


#run model
lr1.fit(X=X_train, y=y_train)


#validation of data 
print ("\ntrain:")
print("Slope:",lr1.coef_)
print("Intercept:",lr1.intercept_)
print("R2:",lr1.score(X_train,y_train))
# Out:
# test:
# Slope: [[171.10240813  -0.71881206   0.19126106]]
# Intercept: [-481.45663147]
# R2: 0.33489956728808834
#
# train:
# Slope: [[158.84573811  -0.78352919   0.22007255]]
# Intercept: [-436.80759116]
# R2: 0.30991886136357527
